# %%
import openpyxl

# %%
import pandas as pd

# %%
workbook=openpyxl.Workbook()
sheet=workbook.active

# %%
data=[
    ['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'],
    ['Jo', 'Testing', 25, 'Che', 5000, 2],
    ['Hiti', 'Java', 28, 'Guj', 10000, 3],
    ['San', 'BA', 39, 'Hyd', 15000, 4],
    ['Su', 'HR', 38, 'Bgl', 20000, 5],
    ['Shob', 'SF', 35, 'USA', 25000, 6]
]
for row in data:
    sheet.append(row)

workbook.save('data.xlsx')

# %%
data
# Out:
# [['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'],
#  ['Jo', 'Testing', 25, 'Che', 5000, 2],
#  ['Hiti', 'Java', 28, 'Guj', 10000, 3],
#  ['San', 'BA', 39, 'Hyd', 15000, 4],
#  ['Su', 'HR', 38, 'Bgl', 20000, 5],
#  ['Shob', 'SF', 35, 'USA', 25000, 6]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
emp = pd.read_excel(r'C:\\Users\\hp\\data.xlsx')
emp
# Out:
#    Name   Domain  Age Location  Salary  Exp
# 0    Jo  Testing   25      Che    5000    2
# 1  Hiti     Java   28      Guj   10000    3
# 2   San       BA   39      Hyd   15000    4
# 3    Su       HR   38      Bgl   20000    5
# 4  Shob       SF   35      USA   25000    6

# %%
emp.shape
# Out:
# (5, 6)

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 5

# %%
emp['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    25000
# Name: Salary, dtype: int64

# %%
emp[['Salary','Exp']]
# Out:
#    Salary  Exp
# 0    5000    2
# 1   10000    3
# 2   15000    4
# 3   20000    5
# 4   25000    6

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vis1 = sns.displot(emp['Salary'])

# %%
vis2 = sns.distplot(emp['Salary'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30724\3650463641.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(emp['Salary'])

# %%
vis3=plt.hist(emp['Salary'])

# %%
plt.rcParams['figure.figsize'] = 4,1

# %%
vis4 = sns.lmplot(data=emp, x='Exp',y='Salary')

# %%
vis5 = sns.lmplot(data=emp, x='Exp',y='Salary', fit_reg = False)

# %%
vis6 = sns.lmplot(data=emp, x='Exp',y='Salary', fit_reg = True)
